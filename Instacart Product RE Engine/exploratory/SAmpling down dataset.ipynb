# %%
#https://www.kaggle.com/philippsp/exploratory-analysis-instacart

# %% [markdown]
# <img src='./er_diagram.png'>

# %%
import pandas as pd

# %%
df_aisles = pd.read_csv("../datasets/aisles.csv")

# %%
df_department = pd.read_csv("../datasets/departments.csv")

# %%
df_products = pd.read_csv("../datasets/products.csv")

# %%
df_order_products__prior = pd.read_csv("../datasets/order_products__prior.csv")

# %%
df_order_products__train = pd.read_csv("../datasets/order_products__train.csv")

# %%
df_orders = pd.read_csv("../datasets/orders.csv")

# %%
pd.options.display.float_format = '{:,.2f}'.format
df_order_products__prior.describe()
# Out:
#            order_id    product_id  add_to_cart_order     reordered
# count 32,434,489.00 32,434,489.00      32,434,489.00 32,434,489.00
# mean   1,710,748.52     25,576.34               8.35          0.59
# std      987,300.70     14,096.69               7.13          0.49
# min            2.00          1.00               1.00          0.00
# 25%      855,943.00     13,530.00               3.00          0.00
# 50%    1,711,048.00     25,256.00               6.00          1.00
# 75%    2,565,514.00     37,935.00              11.00          1.00
# max    3,421,083.00     49,688.00             145.00          1.00

# %%
pd.options.display.float_format = '{:,.2f}'.format
df_order_products__train.describe()
# Out:
#           order_id   product_id  add_to_cart_order    reordered
# count 1,384,617.00 1,384,617.00       1,384,617.00 1,384,617.00
# mean  1,706,297.62    25,556.24               8.76         0.60
# std     989,732.65    14,121.27               7.42         0.49
# min           1.00         1.00               1.00         0.00
# 25%     843,370.00    13,380.00               3.00         0.00
# 50%   1,701,880.00    25,298.00               7.00         1.00
# 75%   2,568,023.00    37,940.00              12.00         1.00
# max   3,421,070.00    49,688.00              80.00         1.00

# %%
pd.options.display.float_format = '{:,.2f}'.format
df_orders.describe()
# Out:
# C:\Users\540607\AppData\Roaming\Python\Python35\site-packages\numpy\lib\function_base.py:4116: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
#           order_id      user_id  order_number    order_dow  order_hour_of_day  \
# count 3,421,083.00 3,421,083.00  3,421,083.00 3,421,083.00       3,421,083.00
# mean  1,710,542.00   102,978.21         17.15         2.78              13.45
# std     987,581.74    59,533.72         17.73         2.05               4.23
# min           1.00         1.00          1.00         0.00               0.00
# 25%     855,271.50    51,394.00          5.00         1.00              10.00
# 50%   1,710,542.00   102,689.00         11.00         3.00              13.00
# 75%   2,565,812.50   154,385.00         23.00         5.00              16.00
# max   3,421,083.00   206,209.00        100.00         6.00              23.00
#
#        days_since_prior_order
# count            3,214,874.00
# ...

# %%
len(df_order_products__prior),len(df_order_products__train),len(df_orders)
# Out:
# (32434489, 1384617, 3421083)

# %%
32434489+ 1384617 , 3421083
# Out:
# (33819106, 3421083)

# %%
(df_order_products__prior).columns,(df_order_products__train).columns,(df_orders).columns
# Out:
# (Index(['order_id', 'product_id', 'add_to_cart_order', 'reordered'], dtype='object'),
#  Index(['order_id', 'product_id', 'add_to_cart_order', 'reordered'], dtype='object'),
#  Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#         'order_hour_of_day', 'days_since_prior_order'],
#        dtype='object'))

# %%
# so prior and train contains the same columns 
# orders contain the user_id, eval_set

# %%
len(df_orders["user_id"].unique()),len(df_orders)
# Out:
# (206209, 3421083)

# %%
df_orders.sort_values(["user_id","order_number"]).head(35)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   1187899        1    train            11          4                  8
# ...

# %% [markdown]
# # so in orders every users purchase history is given here we can see that user 1 has made 10 purchases we have to predict what he is gonna buy 11th time

# %%
df_order_products__prior.head(20)
# Out:
#     order_id  product_id  add_to_cart_order  reordered
# 0          2       33120                  1          1
# 1          2       28985                  2          1
# 2          2        9327                  3          0
# 3          2       45918                  4          1
# 4          2       30035                  5          0
# 5          2       17794                  6          1
# 6          2       40141                  7          1
# 7          2        1819                  8          1
# 8          2       43668                  9          0
# 9          3       33754                  1          1
# 10         3       24838                  2          1
# 11         3       17704                  3          1
# 12         3       21903                  4          1
# 13         3       17668                  5          1
# 14         3       46667                  6          1
# 15         3       17461                  7          1
# ...

# %%
df[:10000]

# %% [markdown]
# # have to sample down orders to a managable number

# %%
df_orders_sample = df_orders[df_orders["user_id"] < 6045]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-c5c805598a0d> in <module>()
# ----> 1 df_orders_sample = df_orders[df_orders["user_id"] < 6000]
#
# NameError: name 'df_orders' is not defined

# %%
len(df_orders_sample)
# Out:
# 99998

# %%
df_orders_sample.to_csv("orders_sample.csv")

# %%
del df_orders

# %%
df_orders_sample.tail(20)
# Out:
#        order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 99978    812267     6043    prior             1          0                 10
# 99979   1368288     6043    prior             2          5                 14
# 99980   1536007     6043    prior             3          3                 11
# 99981   3145512     6043    prior             4          6                  8
# 99982   1334050     6043    prior             5          4                 11
# 99983   1217160     6043    prior             6          2                 11
# 99984   1288236     6043    prior             7          0                 13
# 99985   1660291     6043     test             8          4                  8
# 99986   3362871     6044    prior             1          0                 16
# 99987   2371772     6044    prior             2          1                 16
# 99988    573960     6044    prior             3          0                 19
# ...

# %%
df_orders_sample.sort_values("order_id").head(4)
# Out:
#        order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 50028         8     3107    prior             5          4                  6
# 6226         40      382    prior            29          1                 15
# 89599        64     5430    prior             8          0                 16
# 94894        67     5738    prior             4          3                 12
#
#        days_since_prior_order
# 50028                   17.00
# 6226                    23.00
# 89599                    6.00
# 94894                    6.00

# %%
df_order_products__prior.sort_values("order_id").head(5)
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
# remove the unused orders from prior df

# %%
len(df_orders_sample["order_id"])
# Out:
# 99998

# %%
df_order_products__prior = df_order_products__prior[df_order_products__prior["order_id"].isin(df_orders_sample["order_id"])]

# %%
len(df_order_products__prior)
# Out:
# 936140

# %%
df_order_products__prior.sort_values("order_id").head(10)
# Out:
#      order_id  product_id  add_to_cart_order  reordered
# 61          8       23423                  1          1
# 333        40       10070                  1          1
# 334        40       42450                  2          1
# 335        40       33198                  3          1
# 336        40       34866                  4          1
# 535        64       17889                  1          1
# 536        64        9292                  2          1
# 537        64       15424                  3          1
# 538        64       18988                  4          1
# 539        64       38959                  5          1

# %%
df_order_products__prior.to_csv("df_order_products__prior_sample.csv")
